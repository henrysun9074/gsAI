# %%
import pandas as pd
import numpy as np
import joblib
from plotnine import *
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from xgboost import XGBClassifier
import xgboost as xgb
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

gb_model = joblib.load("models/Oct22_MAF01/GB_best_model.joblib")
rf_model = joblib.load("models/Oct22_MAF01/RF_best_model.joblib")
lr_model = joblib.load("models/Oct22_MAF01/LR_best_model.joblib")
# Out:
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/pickle.py:1710: UserWarning: [15:24:25] WARNING: /workspace/src/gbm/gbtree.cc:384: Changing updater from `grow_gpu_hist` to `grow_quantile_histmaker`.
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/pickle.py:1710: UserWarning: [15:24:25] WARNING: /workspace/src/context.cc:49: No visible GPU is found, setting device to CPU.
# /hpc/group/schultzlab/hs325/miniconda3/envs/gsAI/lib/python3.12/pickle.py:1710: UserWarning: [15:24:25] WARNING: /workspace/src/context.cc:203: XGBoost is not compiled with CUDA support.

# %%
fig, ax = plt.subplots(figsize=(14, 20))  # width=14, height=30 for tall plots

# Plot feature importance
xgb.plot_importance(
    gb_model,
    importance_type="weight",
    max_num_features=100,
    ax=ax
)

# Adjust title and layout
plt.tight_layout(pad=2.0)  # adds spacing between elements
plt.show()
